# %%
import os
import sys
sys.path.append(os.pardir)
from dataset.mnist import *

import numpy as np
import matplotlib.pyplot as plt
from simpleDL.model import *
from simpleDL.function_class import *
from simpleDL.function import *
from simpleDL.data import *
from simpleDL.optimizer import *
from simpleDL.trainer import *

# %%
(x_train, y_train), (x_test, y_test) = load_mnist(flatten=False)

# %%
x_train[1].shape
# Out:
# (1, 28, 28)

# %%
network = Model(
    ConvLayer(input_channel = 1, output_channel = 30, kernel_size = 5, stride = 1, padding=0),
    ReLU(),
    MaxPoolingLayer(kernel_size=2, stride=2),
    DenseLayer(4320, 100),
    ReLU(),
    DenseLayer(100, 10)
)

# %%
print(network)
# Out:
# 0. ConvLayer1 : ConvLayer (30, 1, 5, 5)
# 1. Function1 : Function
# 2. MaxPoolingLayer1 : MaxPoolingLayer
# 3. DenseLayer1 : DenseLayer (4320, 100)
# 4. Function2 : Function
# 5. DenseLayer2 : DenseLayer (100, 10)

# %%
epochs = 3
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
train_acc_list = []
test_acc_list = []

# %%
iter_per_epoch = max(train_size / batch_size, 1)
critic = CrossEntropyLoss()

# %%
train_data = DataLoader(x_train, y_train, batch_size=batch_size)
valid_data = DataLoader(x_test, y_test, batch_size=batch_size)
optim = Adam()

# %%
mnist_trainer = ClassificationTrainer(network,
                                    critic,
                                    optim,
                                    epochs,
                                    init_lr = 0.001
                                    )

# %%
mnist_trainer.train(train_data, valid_data)
# Out:
# epoch 1
#   0%|          | 0/600 [00:00<?, ?it/s]
# train loss : 0.18412669671486437    train accuarcy : 95.0766666666666752
# epoch 1 -- train loss : 0.9877045820413849    train accuarcy : 95.07666666666667
#   0%|          | 0/100 [00:00<?, ?it/s]
# valid loss : 0.06216671293452505    valid accuarcy : 98.0700000000000166
# epoch 1 -- valid loss : 0.059639100260545766    valid accuarcy : 98.07000000000001
# --------------------------------
# epoch 2
#   0%|          | 0/600 [00:00<?, ?it/s]
# train loss : 0.023832335053040592    train accuarcy : 98.11428571428571
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/augustin/Library/CloudStorage/GoogleDrive-2bambitious@gmail.com/My Drive/DL-Implement/CNN/cnn_float32.ipynb 셀 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/augustin/Library/CloudStorage/GoogleDrive-2bambitious%40gmail.com/My%20Drive/DL-Implement/CNN/cnn_float32.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> mnist_trainer.train(train_data, valid_data)
#
# File ~/Library/CloudStorage/GoogleDrive-2bambitious@gmail.com/My Drive/DL-Implement/CNN/../simpleDL/trainer.py:93, in ClassificationTrainer.train(self, train_dataloader, valid_dataloader)
#      91 y_num = 0
#      92 for x, y in tqdm(train_dataloader):
# ---> 93     train_loss = self._forward(x, y)
#      94     tmp_train_loss = np.append(tmp_train_loss, train_loss)
#      95     pred = np.argmax(self.critic.pred, axis=1)
#
# File ~/Library/CloudStorage/GoogleDrive-2bambitious@gmail.com/My Drive/DL-Implement/CNN/../simpleDL/trainer.py:60, in ClassificationTrainer._forward(self, x, y)
#      59 def _forward(self, x, y):
# ---> 60     pred = self.model(x)
#      61     loss = self.critic(pred, y)
#      63     return loss
#
# File ~/Library/CloudStorage/GoogleDrive-2bambitious@gmail.com/My Drive/DL-Implement/CNN/../simpleDL/model.py:460, in Model.__call__(self, arg)
#     459 def __call__(self, arg):
# --> 460     result = self._forward(arg)
#     461     return result
#
# File ~/Library/CloudStorage/GoogleDrive-2bambitious@gmail.com/My Drive/DL-Implement/CNN/../simpleDL/model.py:485, in Model._forward(self, x)
#     483 for layer_name in self.sequence:
#     484     layer = self.network[layer_name]
# --> 485     y = layer(input)
#     486     input = y
#     488 return input
#
# File ~/Library/CloudStorage/GoogleDrive-2bambitious@gmail.com/My Drive/DL-Implement/CNN/../simpleDL/model.py:349, in MaxPoolingLayer.__call__(self, arg)
#     348 def __call__(self, arg):
# --> 349     result = self._forward(arg)
#     350     return result
#
# File ~/Library/CloudStorage/GoogleDrive-2bambitious@gmail.com/My Drive/DL-Implement/CNN/../simpleDL/model.py:359, in MaxPoolingLayer._forward(self, x)
#     356 out_height = int(1 + (input_height + self.padding * 2 - self.kernel_height) / self.stride)
#     357 out_width = int(1 + (input_width + self.padding * 2 - self.kernel_width) / self.stride)
# --> 359 col = self.img2col(x)
#     360 col = col.reshape(-1, self.kernel_height * self.kernel_width)
#     362 self.x = x
#
# File ~/Library/CloudStorage/GoogleDrive-2bambitious@gmail.com/My Drive/DL-Implement/CNN/../simpleDL/model.py:389, in MaxPoolingLayer.img2col(self, input_data)
#     386 out_width = (input_width + self.padding * 2 -self.kernel_width) // self.stride + 1
#     388 img = np.pad(input_data, [(0,0), (0,0), (self.padding, self.padding), (self.padding, self.padding)], 'constant')
# --> 389 col = np.zeros((n_input, n_input_channel, self.kernel_height, self.kernel_width, out_height, out_width)).astype(np.float32)
#     391 for y in range(self.kernel_height):
#     392     y_max = y + self.stride * out_height
#
# KeyboardInterrupt:

# %%
mnist_trainer.show_error_graph()

# %%
mnist_trainer.show_accuracy_graph()

# %%
for epoch in range(10):
    train_correct_count = 0
    test_correct_count = 0
    for x, y in train_data:
        pred = network(x)
        train_loss = critic(pred, y)
        p = np.argmax(critic.pred, axis=1)
        if y.ndim != 1:
            y = np.argmax(y, axis=1)
        train_loss_list.append(train_loss)
        network._backward(critic)

        grad = network.gradient()
        
        optim.update(network)

        train_correct_count += np.sum(p==y)


    for x, y in test_data:
        pred = network(x)
        softmax(pred)
        p = np.argmax(pred, axis=1)
        if y.ndim != 1:
            y = np.argmax(y, axis=1)
        test_correct_count += np.sum(p==y)


    train_acc = float(train_correct_count)/len(x_train)
    train_acc_list.append(train_acc)
    test_acc = float(test_correct_count)/len(x_test)
    test_acc_list.append(test_acc)
    print(f"train acc : {train_acc}")
    print(f"test acc : {test_acc}")
